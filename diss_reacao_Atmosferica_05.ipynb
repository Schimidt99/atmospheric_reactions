# %% [markdown]
# # Attack of atomic oxygen on the double bonds of aliphatic chains

# %% [markdown]
# **reactions with 3 distinct mechanisms and products**
#
# https://ntrs.nasa.gov/citations/20170006623

# %%
# Install RDKit.
# %%capture
# !pip install rdkit

# %%
import rdkit
from rdkit import Chem
from rdkit.Chem import AllChem
import os
print('RDKit version: ', rdkit.__version__)

from rdkit.Chem import Draw
from rdkit.Chem.Draw import IPythonConsole
rdkit.RDLogger.DisableLog('rdApp.*')  # Suppress RDKit error messages
# Out:
# RDKit version:  2025.03.4

# %% [markdown]
# TXT file with specific SMILES molecules of DIESEL fuel

# %%
os.chdir("/content/")

file_name = 'smiles-diesel.txt'  # fazer o upload do arq TXT na pasta 'content' do Colab antes de tudo

# mechanism 'A'

reacao = AllChem.ReactionFromSmarts('[*:0]-[C;!a:1]=[C;!a:2]-[*:3]>>[C:2]-[C:1](-[*:0])=O')

# %%
with open(file_name, "r") as f, open('sanitize05a.txt', 'w') as f_out:
    smiles = []
    all_products = []  # Initialize all_products before the loop
    for line in f:
        smiles.append(line.split('\n')[0])
        m = Chem.MolFromSmiles(line)
        if m is None:
            continue
        ps = reacao.RunReactants((m,))
        # Sanitize each product molecule individually
        tp = 0    # contador de moleculas sanitizadas
        for product_tuple in ps:
            for product_mol in product_tuple:
                try:
                    Chem.SanitizeMol(product_mol)  #verificando a "existencia" da molecula
                    tp = tp + 1
                except:
                    continue # Skip to the next molecule

                all_products.append(product_mol) #add the sanitized molecule

        #print(tp) # total de  moleculas sanitizadas por reagente
        f_out.write(str(tp) + '\n')

# %% [markdown]
# Display unique products - mechanism 'A'

# %%
unique_products = []
product_smiles = set()
for mol in all_products:
    smi = Chem.MolToSmiles(mol)
    if smi not in product_smiles:
        product_smiles.add(smi)
        unique_products.append(mol)
len(unique_products) #total of unique_products
# Out:
# 8

# %%
# saving the sanitized products in 'saida5a.txt'
with open('saida5a.txt', 'w') as f:
    for mol in unique_products:
        smi = Chem.MolToSmiles(mol)
        f.write(smi + '\n')

# %%
Draw.MolsToGridImage(unique_products, molsPerRow=4)

# %%
# mechanism 'B'

reacao = AllChem.ReactionFromSmarts('[*:0]-[C;!a:1]=[C;!a:2]>>[O:3]-[C:2]=[C:1]-[*:0]')

# %%
with open(file_name, "r") as f, open('sanitize05b.txt', 'w') as f_out:
    smiles = []
    all_products = []  # Initialize all_products before the loop
    for line in f:
        smiles.append(line.split('\n')[0])
        m = Chem.MolFromSmiles(line)
        if m is None:
            continue
        ps = reacao.RunReactants((m,))
        # Sanitize each product molecule individually
        tp = 0    # contador de moleculas sanitizadas
        for product_tuple in ps:
            for product_mol in product_tuple:
                try:
                    Chem.SanitizeMol(product_mol)  #verificando a "existencia" da molecula
                    tp = tp + 1
                except:
                    continue # Skip to the next molecule

                all_products.append(product_mol) #add the sanitized molecule

        #print(tp) # total de  moleculas sanitizadas por reagente
        f_out.write(str(tp) + '\n')

# %% [markdown]
# Display unique products - mechanism 'B'

# %%
unique_products = []
product_smiles = set()
for mol in all_products:
    smi = Chem.MolToSmiles(mol)
    if smi not in product_smiles:
        product_smiles.add(smi)
        unique_products.append(mol)
len(unique_products) #total of unique_products
# Out:
# 6

# %%
# saving the sanitized products in 'saida5b.txt'
with open('saida5b.txt', 'w') as f:
    for mol in unique_products:
        smi = Chem.MolToSmiles(mol)
        f.write(smi + '\n')

# %%
Draw.MolsToGridImage(unique_products, molsPerRow=4)

# %%
# mechanism 'C'

reacao = AllChem.ReactionFromSmarts('[*:0]-[C;!a:1]=[C;!a:2]>>[*:0]-[C:1]-1-[C:2]-[O]-1')

# %%
with open(file_name, "r") as f, open('sanitize05c.txt', 'w') as f_out:
    smiles = []
    all_products = []  # Initialize all_products before the loop
    for line in f:
        smiles.append(line.split('\n')[0])
        m = Chem.MolFromSmiles(line)
        if m is None:
            continue
        ps = reacao.RunReactants((m,))
        # Sanitize each product molecule individually
        tp = 0    # contador de moleculas sanitizadas
        for product_tuple in ps:
            for product_mol in product_tuple:
                try:
                    Chem.SanitizeMol(product_mol)  #verificando a "existencia" da molecula
                    tp = tp + 1
                except:
                    continue # Skip to the next molecule

                all_products.append(product_mol) #add the sanitized molecule

        #print(tp) # total de  moleculas sanitizadas por reagente
        f_out.write(str(tp) + '\n')

# %% [markdown]
# Display unique products - mechanism 'B'

# %%
unique_products = []
product_smiles = set()
for mol in all_products:
    smi = Chem.MolToSmiles(mol)
    if smi not in product_smiles:
        product_smiles.add(smi)
        unique_products.append(mol)
len(unique_products) #total of unique_products
# Out:
# 5

# %%
# saving the sanitized products in 'saida5c.txt'
with open('saida5c.txt', 'w') as f:
    for mol in unique_products:
        smi = Chem.MolToSmiles(mol)
        f.write(smi + '\n')

# %%
Draw.MolsToGridImage(unique_products, molsPerRow=4)
